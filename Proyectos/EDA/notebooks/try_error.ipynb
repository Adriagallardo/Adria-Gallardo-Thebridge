# %%
#Este archivo guarda intentos de ejecución del archivo main que se han decidido no incorporar en el proyecto.

# %%
#imports
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Primero agregamos la ruta a los archivos src y reports, donde guardamos las funciones generadas y las figuras que sacamos de main
import os, sys
ruta = os.path.dirname(os.getcwd())
sys.path.append(ruta)
sys.path
# Out:
# ['c:\\Users\\Adrià\\Desktop\\Thebridge\\adria_gallardo_thebridge_ds\\Proyectos\\EDA\\notebooks',
#  'c:\\Users\\Adrià\\.vscode\\extensions\\ms-toolsai.jupyter-2021.6.832593372\\pythonFiles',
#  'c:\\Users\\Adrià\\.vscode\\extensions\\ms-toolsai.jupyter-2021.6.832593372\\pythonFiles',
#  'c:\\Users\\Adrià\\.vscode\\extensions\\ms-toolsai.jupyter-2021.6.832593372\\pythonFiles\\lib\\python',
#  'C:\\Users\\Adrià\\AppData\\Local\\Programs\\Python\\Python37\\python37.zip',
#  'C:\\Users\\Adrià\\AppData\\Local\\Programs\\Python\\Python37\\DLLs',
#  'C:\\Users\\Adrià\\AppData\\Local\\Programs\\Python\\Python37\\lib',
#  'C:\\Users\\Adrià\\AppData\\Local\\Programs\\Python\\Python37',
#  '',
#  'C:\\Users\\Adrià\\AppData\\Roaming\\Python\\Python37\\site-packages',
#  'C:\\Users\\Adrià\\AppData\\Roaming\\Python\\Python37\\site-packages\\win32',
#  'C:\\Users\\Adrià\\AppData\\Roaming\\Python\\Python37\\site-packages\\win32\\lib',
# ...

# %%
import src.utils.folders_tb as fol

# %%
#Se está utilizando orientación "split" para almacenar json, no se puede utilizar la formula de folders_tb.
data = pd.DataFrame.from_dict(fol.read_json(".." + os.sep + "reports" + os.sep + "from_main" + os.sep + "cleaned_data.json"))
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-85afd9271309> in <module>
#       1 #Se está utilizando orientación "split" para almacenar json, no se puede utilizar la formula de folders_tb.
# ----> 2 data = pd.DataFrame.from_dict(fol.read_json(".." + os.sep + "reports" + os.sep + "from_main" + os.sep + "cleaned_data.json"))
#       3 data
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1371             raise ValueError("only recognize index or columns for orient")
#    1372
# -> 1373         return cls(data, index=index, columns=columns, dtype=dtype)
#    1374
#    1375     def to_numpy(
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
# ...

# %%
#read_json de Pandas funciona bien.
data = pd.read_json((".." + os.sep + "reports" + os.sep + "from_main" + os.sep + "cleaned_data.json"), orient="split")
data
# Out:
#      sex  age address famsize Pstatus  Medu  Fedu  reason guardian  \
# 0      F   18       U     GT3       A     4     4  course   mother
# 1      F   17       U     GT3       T     1     1  course   father
# 2      F   15       U     LE3       T     1     1   other   mother
# 3      F   15       U     GT3       T     4     2    home   mother
# 4      F   16       U     GT3       T     3     3    home   father
# ...   ..  ...     ...     ...     ...   ...   ...     ...      ...
# 1010   F   19       R     GT3       T     2     3  course   mother
# 1011   F   18       U     LE3       T     3     1  course   mother
# 1012   F   18       U     GT3       T     1     1  course   mother
# 1013   M   17       U     LE3       T     3     1  course   mother
# 1014   M   18       R     LE3       T     3     2  course   mother
#
#       traveltime  ...  nursery  higher internet romantic famrel freetime  \
# 0              2  ...      yes     yes       no       no      4        3
# ...

# %%
#Sacar subplots con seaborn. Catplot da error
fig, ax = plt.subplots(1,2, figsize=(12,6))
sns.catplot(data=data, x="age", y="alcohol", kind= "bar", hue="sex", ax=ax[0])
sns.catplot(data=data, x="age", y="grade", kind="bar", hue="sex", ax=ax[1])
# Out:
# C:\Users\Adrià\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3772: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try barplot
#   warnings.warn(msg, UserWarning)
# C:\Users\Adrià\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\categorical.py:3772: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try barplot
#   warnings.warn(msg, UserWarning)

# %%
#Sacar subplots con seaborn. Pruebo barplot.abs
fig, ax = plt.subplots(1,2, figsize=(12,6))
sns.barplot(data=data, x="age", y="alcohol", hue="sex", ax=ax[0])
sns.barplot(data=data, x="age", y="grade", hue="sex", ax=ax[1])
# Out:
# <AxesSubplot:xlabel='age', ylabel='grade'>

# %%
#Crear plots para analizar como evolucionan algunos parámetros a medida que avanza la edad para sexos distintos. No me convencen los que salen lateralmente, salen así porque son binarios.
fig, ax = plt.subplots(3,3, figsize=(22,11))
sns.barplot(data=data, x="age", y="studytime", hue="sex", ax=ax[0,0])
sns.barplot(data=data, x="age", y="goout", hue="sex", ax=ax[0,1])
sns.barplot(data=data, x="age", y="absences", hue="sex", ax=ax[0,2])
sns.barplot(data=data, x="age", y="paid", hue="sex", ax=ax[1,0])
sns.barplot(data=data, x="age", y="activities", hue="sex", ax=ax[1,1])
sns.barplot(data=data, x="age", y="romantic", hue ="sex", ax=ax[1,2])
sns.barplot(data=data, x="age", y="internet", hue="sex", ax=ax[2,0])
sns.barplot(data=data, x="age", y="schoolsup", hue="sex", ax=ax[2,1])
sns.barplot(data=data, x="age", y="nursery", hue="sex", ax=ax[2,2])
# Out:
# <AxesSubplot:xlabel='age', ylabel='nursery'>

# %%
#Sacar treemap
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import squarify

data = pd.read_csv("Data/ManCityATT.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5e8d85963040> in <module>
#       5 import squarify
#       6
# ----> 7 data = pd.read_csv("Data/ManCityATT.csv")
#       8 data.head()
#
# ...

# %%
dataGoals = data[data["G"]>0]


fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(16, 4.5)
squarify.plot(label=dataGoals.Player,sizes=dataGoals.G, alpha=.6)

plt.title("Man City Goals",fontsize=23,fontweight="bold")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-240f86e24742> in <module>
# ----> 1 dataGoals = data[data["G"]>0]
#       2 norm = matplotlib.colors.Normalize(vmin=min(dataGoals.G), vmax=max(dataGoals.G))
#       3 colors = [matplotlib.cm.Blues(norm(value)) for value in dataGoals.G]
#       4 fig = plt.gcf()
#       5 ax = fig.add_subplot()
#
# NameError: name 'data' is not defined
