# %% [markdown]
# # Test DS-FT April 2021

# %% [markdown]
# ## Primera parte (tipo test):
#
# https://forms.gle/24Eu5xuFGn6jNKpx9

# %% [markdown]
# -----------------

# %% [markdown]
# ## Segunda parte, ejercicios prácticos:
#
# * El test práctico consta de 5 ejercicios puntuables.
# * Cada uno se puntúa sobre 2,5.
# * La máxima nota es 10.

# %% [markdown]
# Antes de comenzar, cambia el nombre del archivo notebook poniéndole delante tu nombre y primer apellido:
#
# * nombre_apellido_test_pract_apr_2021.ipynb

# %%
# Escribe tu nombre en la variable:
nombre_y_apellidos = "Adrià Gallardo Viñas"

# %% [markdown]
# #### Notas y pruebas de apoyo para contestar las preguntas tipo test
# Esto no es necesario usarlo aunque verlo aquí te puede dar la respuesta a alguna de las preguntas tipo test.
#
# Cualquier código aunque no esté correcto nos dirá más de ti que no escribir nada.

# %%
# Ejemplo de como queremos ver el código para más de un intento:

# intento 1
your code
# intento 2
your code

# %%
# crea todas las celdas que necesites

# %% [markdown]
# ## Ejercicios prácticos

# %% [markdown]
# #### Ejercicio 1.
# En este ejercicio se va a crear una lista con los siguientes elementos. Primero, crearemos las variables que luego añadiremos a la lista. Las variables son las siguientes:
#
# 1. Crea una variable llamada `num_dni` de tipo Integer que represente el primer número de tu DNI.
# 2. Crea una variable llamada `let_dni` de tipo String y que represente la letra de vuestro DNI.
# 3. Crea una variable llamada `tip_ord` de tipo Boolean True si usas Windows y False si usas Mac.
# 4. Crea una variable llamada `nada` de tipo None cuyo valor sea None.
# 5. Crea una variable llamada `lista_deseo` de tipo List que contenga los cuatro objetos que te llevarías a una isla desierta. Cada elemento ha de ser de tipo String y el tamaño de la lista ha de ser 4.
# 6. Crea una variable llamada `tupla_ropa` de tipo Tuple con la marca de la prenda superior, inferior y calzado que llevas puesto.
# 7. Crea una variable llamada `dict_info` con dos keys y dos values. Una key es 'nombre', teniendo como value vuestro nombre. Otra key es 'edad', teniendo como value vuestra edad.
# 8. Crea una variable llamada `flo_hor` con la hora actual separada por punto en vez de dos puntos. Ejemplo: si son las 10:06, el valor de la variable sería 10.06.
#
# Añade todos estos elementos en una lista llamada `lista_examen` en el orden de aparición.

# %%
 # tu respuesta aquí

num_dni = 2
let_dni = "M"
tip_ord = True
nada = None
lista_deseo = ["pan", "carne", "agua", "pelota"]
tupla_ropa = ("camiseta", "pantalon corto", "zapatillas")
dict_info = {"nombre": "Adrià" , "edad": 24}
flor_hor = 10.02

lista_examen = [num_dni, let_dni, tip_ord, nada, lista_deseo, tupla_ropa, dict_info, flor_hor]
lista_examen
# Out:
# [2,
#  'M',
#  True,
#  None,
#  ['pan', 'carne', 'agua', 'pelota'],
#  ('camiseta', 'pantalon corto', 'zapatillas'),
#  {'nombre': 'Adrià', 'edad': 24},
#  10.02]

# %% [markdown]
# #### Ejercicio 2.
#
# Para resolver este ejercicio necesitarás la lista del ejercicio anterior (`lista_examen`). Se recomeinda leer cada punto hasta el final antes de resolver el ejercicio.
#
# Se repite para que quede aún más claro: **SOLO USAR LA VARIABLE** `lista_examen`. Usar las demás variables se calificará como error.
#
# 1. Mostrar por pantalla, sin uso de funciones ni bucles:
#     - El segundo elemento de `lista_deseo` desde `lista_examen`.
#     - El calzado que llevas puesto.
#     - Vuestro nombre.
#     - La hora almacenada concatenada con vuestra edad y el número de vuestro de DNI. No debe haber espacios entre la concatenación.
#     - Si tenéis más de 20 años, el primer número de vuestro DNI es mayor a 7 y usas Mac, mostrar la posición 5 de `lista_examen`.

# %%
# segundo elemento
print(lista_examen[4][1])
# Out:
# carne

# %%
# calzado
print(lista_examen[5][-1])
# Out:
# zapatillas

# %%
# nombre
print(lista_examen[-2]["nombre"])
# Out:
# Adrià

# %%
# hora almacenada concatenada con vuestra edad y el número de vuestro de DNI. sin espacios
print(lista_examen[-1]+lista_examen[-2]["edad"]+lista_examen[0])
# Out:
# 36.019999999999996

# %%
# si > 20 ....
if lista_examen[-2]["edad"] > 20 and lista_examen[0] > 7 and list_examen[2] == False:
    print(lista_examen[5])

# %% [markdown]
# 2. Mostrar por pantalla, con uso de un bucle `for`:
#     - Todos los elementos de `lista_examen`.
#     - Todos los elementos de `lista_deseo` desde `lista_examen`.
#     - Todos los elementos que ocupen una posición menor a 4 en `lista_examen`.

# %%
# Todos los elementos de lista_examen.
for elem1 in lista_examen:
    print(elem1)
# Out:
# 2
# M
# True
# None
# ['pan', 'carne', 'agua', 'pelota']
# ('camiseta', 'pantalon corto', 'zapatillas')
# {'nombre': 'Adrià', 'edad': 24}
# 10.02

# %%
# Todos los elementos de lista_deseo desde lista_examen.
for i2, elem2 in enumerate(lista_examen):
    if i2 == 4:
        print(elem2)
# Out:
# ['pan', 'carne', 'agua', 'pelota']

# %%
# Todos los elementos que ocupen una posición menor a 4 en lista_examen.
for i3, elem3 in enumerate(lista_examen):
    if i3 < 4:
        print(elem3)
# Out:
# 2
# M
# True
# None

# %% [markdown]
# 3. Mostrar por pantalla, con uso de un bucle while:
#     - Todos los elementos de `tupla_ropa` seguido de la cadena `"-->"` y la `posición` (int) que ocupa en la tupla accediendo desde `lista_examen`. Se aconseja utilizar *`enumerate`*.
#     - Cada key de `dict_info` seguido de la cadena ":" seguido de su value desde `lista_examen`.

# %%
# Todos los elementos de tupla_ropa seguido de la cadena "-->" y la posición (int) que ocupa en la tupla accediendo desde lista_examen. Se aconseja utilizar enumerate.
c = 0
while c == 0:
    for i4, elem4 in enumerate(lista_examen[5]):
        print(elem4,"-->", i4)
    c += 1
# Out:
# camiseta --> 0
# pantalon corto --> 1
# zapatillas --> 2

# %%
# Todos los elementos de tupla_ropa seguido de la cadena "-->" y la posición (int) que ocupa en la tupla accediendo desde lista_examen. Se aconseja utilizar enumerate.
pos = 0
for elem44 in lista_examen[5]:
    while elem44 in lista_examen[5]:
        print(elem44,"-->", pos)
        pos += 1
        break
# Out:
# camiseta --> 0
# pantalon corto --> 1
# zapatillas --> 2

# %%
#Cada key de dict_info seguido de la cadena ":" seguido de su value desde lista_examen.
cont = 0
while cont == 0:
    for key1, value1 in lista_examen[-2].items():
        print(key1,":",value1)
        cont += 1
# Out:
# nombre : Adrià
# edad : 24

# %% [markdown]
# #### Ejercicio 3.
#
# Crea una función `ejercicio_3` que reciba un parámetro `arg1`. Este argumento se utilizará como la lista de tuplas con nombres de los alumnos y alturas de clase. La función ha de retornar la misma lista de tuplas pero sin la tupla que contiene tu nombre. La tupla que contiene tu nombre ha de encontrarse a través del **valor del String** con tu nombre. Es decir, la función borrará la tupla con tu nombre tanto si está en la primera posición, como en la posición N o la última. La función mostrará por pantalla la tupla modificada.
#
# **Notas:**
#
# *- La lista de nombres y alturas está al final del notebook*
#
# *- Añade la tupla con tu nombre y altura si no apareces en la lista*
#
# Ejemplos de llamada a la función y lo que devuelve la función en el caso en el que me llamo 'Manuel Alfonso' y con esta 'lista_nombres_alturas':

# %%
# NO EJECUTAR ESTA CELDA
lista_nombres_alturas = [("Manuel Alfonso", 1.75),("Jonathan Abbondanza",  1.70),("Nacho Fontal", 1.82)]
ejercicio_3(arg1=lista_nombres_alturas)
# Out:
# [('Jonathan Abbondanza', 1.7), ('Nacho Fontal', 1.82)]

# %%
# NO EJECUTAR ESTA CELDA
lista_nombres_alturas = [("Jonathan Abbondanza",  1.70),("Manuel Alfonso", 1.75),("Nacho Fontal", 1.82)]
ejercicio_3(arg1=lista_nombres_alturas)
# Out:
# [('Jonathan Abbondanza', 1.7), ('Nacho Fontal', 1.82)]

# %%
# intento 1
def ejercicio_3(arg1):
    for tele in arg1:
        if tele[0] == "Adrià Gallardo":
            arg1.remove(tele) 
  
        print("La tupla modificada es", tele)

    return arg1

ejercicio_3(arg1=lista_nombres_alturas)
# Out:
# La tupla modificada es ('Gabriel Vázquez', 1.75)
# La tupla modificada es ('Jonathan Abbondanza', 1.7)
# La tupla modificada es ('Nacho Fontal', 1.82)
# La tupla modificada es ('Javier Araiz', 1.8)
# La tupla modificada es ('Jonathan Suarez', 1.86)
# La tupla modificada es ('Sonia Cobo', 1.73)
# La tupla modificada es ('Jorge García', 1.79)
# La tupla modificada es ('Mary Meza', 1.52)
# La tupla modificada es ('Leonardo Frazzetto', 1.75)
# La tupla modificada es ('Nacho Astorga', 1.78)
# La tupla modificada es ('José Carlos Batista', 1.7)
# La tupla modificada es ('Isabel Palomares', 1.78)
# La tupla modificada es ('Marina Serrano', 1.54)
# La tupla modificada es ('Daniel Walker', 1.87)
# La tupla modificada es ('Clara Piniella', 1.66)
# La tupla modificada es ('Gina Garrido', 1.63)
# La tupla modificada es ('Adrià Gallardo', 1.7)
# La tupla modificada es ('Susana Vázquez', 1.8)
# La tupla modificada es ('Mauro Garcia-Oliva', 1.77)
# La tupla modificada es ('Juan Bayon', 1.64)
# La tupla modificada es ('Miguel Barquero', 1.85)
# La tupla modificada es ('Borja Puig', 1.82)
# La tupla modificada es ('Pablo Martínez', 1.81)
# La tupla modificada es ('Xinru Yang', 1.6)
# La tupla modificada es ('Pablo Díez', 1.84)
# La tupla modificada es ('Karina Inche', 1.61)
# [('Gabriel Vázquez', 1.75),
#  ('Jonathan Abbondanza', 1.7),
#  ('Nacho Fontal', 1.82),
#  ('Javier Araiz', 1.8),
#  ('Jonathan Suarez', 1.86),
#  ('Sonia Cobo', 1.73),
#  ('Jorge García', 1.79),
#  ('Mary Meza', 1.52),
#  ('Leonardo Frazzetto', 1.75),
#  ('Nacho Astorga', 1.78),
#  ('José Carlos Batista', 1.7),
#  ('Isabel Palomares', 1.78),
#  ('Marina Serrano', 1.54),
#  ('Daniel Walker', 1.87),
#  ('Clara Piniella', 1.66),
#  ('Gina Garrido', 1.63),
#  ('María García-Maroto', 1.64),
#  ('Susana Vázquez', 1.8),
#  ('Mauro Garcia-Oliva', 1.77),
#  ('Juan Bayon', 1.64),
#  ('Miguel Barquero', 1.85),
#  ('Borja Puig', 1.82),
#  ('Pablo Martínez', 1.81),
#  ('Xinru Yang', 1.6),
#  ('Pablo Díez', 1.84),
#  ('Karina Inche', 1.61)]

# %%
#intento 2. Solución

def ejercicio_3(arg1):
    for tele in arg1:
        if tele[0] == "Adrià Gallardo":
            arg1.remove(tele) 
  
            print("La tupla modificada es", tele)

    return arg1

ejercicio_3(arg1=lista_nombres_alturas)
# Out:
# La tupla modificada es ('Adrià Gallardo', 1.7)
# [('Gabriel Vázquez', 1.75),
#  ('Jonathan Abbondanza', 1.7),
#  ('Nacho Fontal', 1.82),
#  ('Javier Araiz', 1.8),
#  ('Jonathan Suarez', 1.86),
#  ('Sonia Cobo', 1.73),
#  ('Jorge García', 1.79),
#  ('Mary Meza', 1.52),
#  ('Leonardo Frazzetto', 1.75),
#  ('Nacho Astorga', 1.78),
#  ('José Carlos Batista', 1.7),
#  ('Isabel Palomares', 1.78),
#  ('Marina Serrano', 1.54),
#  ('Daniel Walker', 1.87),
#  ('Clara Piniella', 1.66),
#  ('Gina Garrido', 1.63),
#  ('María García-Maroto', 1.64),
#  ('Susana Vázquez', 1.8),
#  ('Mauro Garcia-Oliva', 1.77),
#  ('Juan Bayon', 1.64),
#  ('Miguel Barquero', 1.85),
#  ('Borja Puig', 1.82),
#  ('Pablo Martínez', 1.81),
#  ('Xinru Yang', 1.6),
#  ('Pablo Díez', 1.84),
#  ('Karina Inche', 1.61)]

# %% [markdown]
# -------------------------------------

# %% [markdown]
# #### Ejercicio 4.
#
# Escribe una función `reverse_number` que reciba dos parámetros. Los parámetros son `cadena` y `n`. `cadena` será un string y `n` un entero. La función debe retornar un string que sea el string `cadena` al revés y que tenga concatenado el número `n` por cada caracter de `cadena`.
#
#
# **No se permite:**
# - Usar la función built-in `reverse`
# - Pasar el string `cadena` a otro tipo de variable (como list)*
# - Usar el `string slicing` [[::-1]]
#
# Ejemplos de llamada a la función y lo que devuelve la función:
#
# --------
#
# >> print(reverse_number(cadena="aloh", n=3))
#
# >>> h3o3l3a3
#
# --------
#
# >> print(reverse_number(cadena="otipep", n=85))
#
# >>> p85e85p85i85t85o85

# %%
#cadena string, n entero. Intento1
def reverse_number (cadena, n):
    anedac = ""
    aument = -1
    for i8, elem8 in enumerate(cadena):
        anedac[aument] = elem8 + n
        aument -= 1    
    
    return anedac

print(reverse_number(cadena="otipep", n=85))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-049505763b85> in <module>
#       9     return anedac
#      10
# ---> 11 print(reverse_number(cadena="otipep", n=85))
#
# <ipython-input-40-049505763b85> in reverse_number(cadena, n)
#       4     aument = -1
#       5     for i8, elem8 in enumerate(cadena):
# ----> 6         anedac[aument] = elem8 + n
#       7         aument -= 1
#       8
#
# TypeError: can only concatenate str (not "int") to str

# %%
#cadena string, n entero. Intento2
def reverse_number (cadena, n):
    anedac = ""
    aument = -1
    for i8, elem8 in enumerate(cadena):
        anedac.append(elem8)
        aument -= 1    
    
    return anedac

print(reverse_number(cadena="otipep", n=85))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-3fdfc0dd2486> in <module>
#       9     return anedac
#      10
# ---> 11 print(reverse_number(cadena="otipep", n=85))
#
# <ipython-input-41-3fdfc0dd2486> in reverse_number(cadena, n)
#       4     aument = -1
#       5     for i8, elem8 in enumerate(cadena):
# ----> 6         anedac.append(elem8)
#       7         aument -= 1
#       8
#
# AttributeError: 'str' object has no attribute 'append'

# %%
#cadena string, n entero. Intento3
def reverse_number (cadena, n):
    anedac = ""
    aument = -1
    for elem8 in cadena:
         anedac = anedac + elem8 + str(n)
         aument -= 1 
    
    return anedac

print(reverse_number(cadena="otipep", n=85))
# Out:
# o85t85i85p85e85p85

# %%
#cadena string, n entero. Intento4: Solución
def reverse_number (cadena, n):
    anedac = ""
    for elem8 in cadena:
         anedac = elem8 + str(n) + anedac
    
    return anedac

print(reverse_number(cadena="otipep", n=85))
# Out:
# p85e85p85i85t85o85

# %%
#ejemplo prueba

def reverse_number (cadena, n):
    anedac = ""
    for elem8 in cadena:
         anedac = elem8 + str(n) + anedac
    
    return anedac

print(reverse_number(cadena="aloh", n=3))
# Out:
# h3o3l3a3

# %% [markdown]
# #### Ejercicio 5:
#  Crea una función `ejercicio_5` que reciba dos parámetros `arg1` y `arg2`. `arg1` es la misma lista de tuplas con los nombres y alturas que la del ejercicio 3 y `arg2` representa un nombre.
# Crea un programa que pida al usuario *indefinidamente* un nombre y, cada vez que lo introduzca, intente borrar de `arg1` la tupla con el nombre introducido usando la función `ejercicio_5`:
#
# 1. Si existe el nombre `arg2` dentro de la `arg1` la función mostrará por pantalla la tupla modificada
#
# 2. Si el nombre `arg2` no está en la lista `arg1` la función mostrará por pantalla el string "Ese
# nombre no está dentro de la lista"
#
# 3. Solo en el caso en el que el usuario escriba la palabra *'STOP'* se parará el programa.
#
# **Notas:**
#
# *- La lista de nombres y alturas está al final del notebook*
#
# *- Añade la tupla con tu nombre y altura si no apareces en la lista*

# %%
#intento1
def ejercicio_5(arg1,arg2):
    while True:
    
        arg2 = input("Por favor, introduzca un nuevo nombre")  
        
        counter = len(arg1)

        for elems in arg1:
        
            if elems[0] == arg2:
                arg1.remove(elems)
                print("Se ha modificado esta tupla:", elems)
            
        if arg2 == "STOP":

            break
        
        if counter == len(arg1):
            print("Ese nombre no está dentro de la lista")



start = ""
ejercicio_5(arg1=lista_nombres_alturas, arg2=start)
# Out:
# Ese nombre no está dentro de la lista
# Ese nombre no está dentro de la lista
# Ese nombre no está dentro de la lista
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-b96bf8709f6b> in <module>
#      29
#      30 start = ""
# ---> 31 ejercicio_5(arg1=lista_nombres_alturas, arg2=start)
#
# <ipython-input-54-b96bf8709f6b> in ejercicio_5(arg1, arg2)
#       2     while True:
#       3
# ----> 4         arg2 = input("Por favor, introduzca un nuevo nombre")
#       5
#       6         counter = len(arg1)
#
# ~\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     849             self._parent_ident,
#     850             self._parent_header,
# --> 851             password=False,
#     852         )
#     853
#
# ~\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#intento2
def ejercicio_5(arg1,arg2):
    while True:
    
        arg2 = input("Por favor, introduzca un nuevo nombre")  
        
        counter = len(arg1)

        for elems in arg1:
        
            if elems[0] == arg2:
                arg1.remove(elems)
                print("Se ha modificado esta tupla:", elems)
            
        if arg2 == "STOP":

            break
        
        if counter == len(arg1):
            print(arg2, "no está dentro de la lista")




start = ""
ejercicio_5(arg1=lista_nombres_alturas, arg2=start)
# Out:
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-312085d572eb> in <module>
#      24
#      25 start = ""
# ---> 26 ejercicio_5(arg1=lista_nombres_alturas, arg2=start)
#
# <ipython-input-55-312085d572eb> in ejercicio_5(arg1, arg2)
#       3     while True:
#       4
# ----> 5         arg2 = input("Por favor, introduzca un nuevo nombre")
#       6
#       7         counter = len(arg1)
#
# ~\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     849             self._parent_ident,
#     850             self._parent_header,
# --> 851             password=False,
#     852         )
#     853
#
# ~\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#intento3
def ejercicio_5(arg1,arg2):
    while arg2 != "STOP":
    
        arg2 = input("Por favor, introduzca un nuevo nombre")  
        
        counter = len(arg1)

        for elems in arg1:
        
            if elems[0] == arg2:
                arg1.remove(elems)
                print("Se ha modificado esta tupla:", elems)
        
        if counter == len(arg1):
            print(arg2, "no está dentro de la lista")




start = ""
ejercicio_5(arg1=lista_nombres_alturas, arg2=start)
# Out:
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
#  no está dentro de la lista
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-99f578c9488f> in <module>
#      20
#      21 start = ""
# ---> 22 ejercicio_5(arg1=lista_nombres_alturas, arg2=start)
#
# <ipython-input-58-99f578c9488f> in ejercicio_5(arg1, arg2)
#       3     while arg2 != "STOP":
#       4
# ----> 5         arg2 = input("Por favor, introduzca un nuevo nombre")
#       6
#       7         counter = len(arg1)
#
# ~\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     849             self._parent_ident,
#     850             self._parent_header,
# --> 851             password=False,
#     852         )
#     853
#
# ~\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#intento4. Solución
def ejercicio_5(arg1,arg2):
    while True:
    
        arg2 = input("Por favor, introduzca un nuevo nombre")  
        
        if arg2 == "STOP":
            break

        counter = 0

        for elems in arg1:
        
            if elems[0] == arg2:
                arg1.remove(elems)
                print("Se ha modificado esta tupla:", elems)

            else:
                counter += 1

        if counter == len(arg1):
            print(arg2, "no está dentro de la lista")

start = ""
ejercicio_5(arg1=lista_nombres_alturas, arg2=start)
# Out:
# aaa no está dentro de la lista
# eee no está dentro de la lista
# Se ha modificado esta tupla: ('Daniel Walker', 1.87)
# Se ha modificado esta tupla: ('Miguel Barquero', 1.85)
# ee no está dentro de la lista

# %%
#comprobación de que ha borrado los elementos de la lista
lista_nombres_alturas
# Out:
# [('Gabriel Vázquez', 1.75),
#  ('Jonathan Abbondanza', 1.7),
#  ('Nacho Fontal', 1.82),
#  ('Javier Araiz', 1.8),
#  ('Jonathan Suarez', 1.86),
#  ('Sonia Cobo', 1.73),
#  ('Jorge García', 1.79),
#  ('Mary Meza', 1.52),
#  ('Leonardo Frazzetto', 1.75),
#  ('Nacho Astorga', 1.78),
#  ('José Carlos Batista', 1.7),
#  ('Isabel Palomares', 1.78),
#  ('Marina Serrano', 1.54),
#  ('Clara Piniella', 1.66),
#  ('Gina Garrido', 1.63),
#  ('Adrià Gallardo', 1.7),
#  ('María García-Maroto', 1.64),
#  ('Susana Vázquez', 1.8),
#  ('Mauro Garcia-Oliva', 1.77),
#  ('Juan Bayon', 1.64),
#  ('Borja Puig', 1.82),
#  ('Pablo Martínez', 1.81),
#  ('Xinru Yang', 1.6),
#  ('Pablo Díez', 1.84),
#  ('Karina Inche', 1.61)]

# %%
# La lista a usar del ejercicio 3 y 5. Recuerda añadir la tupla con tu información si no está. 

lista_nombres_alturas = [("Gabriel Vázquez", 1.75),("Jonathan Abbondanza",  1.70),("Nacho Fontal", 1.82),("Javier Araiz", 1.80),('Jonathan Suarez', 1.86),('Sonia Cobo', 1.73), ('Jorge García', 1.79), ("Mary Meza", 1.52), ('Leonardo Frazzetto', 1.75), ("Nacho Astorga",1.78),("José Carlos Batista",1.70), ("Isabel Palomares", 1.78),("Marina Serrano", 1.54), ("Daniel Walker", 1.87), ("Clara Piniella", 1.66), ("Gina Garrido", 1.63), ("Adrià Gallardo", 1.70), ("María García-Maroto", 1.64), ("Susana Vázquez",1.80), ("Mauro Garcia-Oliva", 1.77), ("Juan Bayon", 1.64), ("Miguel Barquero", 1.85), ("Borja Puig", 1.82), ("Pablo Martínez", 1.81), ("Xinru Yang", 1.60),("Pablo Díez", 1.84),("Karina Inche",1.61)]

lista_nombres_alturas
# Out:
# [('Gabriel Vázquez', 1.75),
#  ('Jonathan Abbondanza', 1.7),
#  ('Nacho Fontal', 1.82),
#  ('Javier Araiz', 1.8),
#  ('Jonathan Suarez', 1.86),
#  ('Sonia Cobo', 1.73),
#  ('Jorge García', 1.79),
#  ('Mary Meza', 1.52),
#  ('Leonardo Frazzetto', 1.75),
#  ('Nacho Astorga', 1.78),
#  ('José Carlos Batista', 1.7),
#  ('Isabel Palomares', 1.78),
#  ('Marina Serrano', 1.54),
#  ('Daniel Walker', 1.87),
#  ('Clara Piniella', 1.66),
#  ('Gina Garrido', 1.63),
#  ('Adrià Gallardo', 1.7),
#  ('María García-Maroto', 1.64),
#  ('Susana Vázquez', 1.8),
#  ('Mauro Garcia-Oliva', 1.77),
#  ('Juan Bayon', 1.64),
#  ('Miguel Barquero', 1.85),
#  ('Borja Puig', 1.82),
#  ('Pablo Martínez', 1.81),
#  ('Xinru Yang', 1.6),
#  ('Pablo Díez', 1.84),
#  ('Karina Inche', 1.61)]
